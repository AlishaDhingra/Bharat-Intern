# %% [markdown]
# <a href="https://colab.research.google.com/github/AlishaDhingra/Bharat-Intern/blob/main/Spam_Msg_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Dataset.csv' , encoding='latin1')

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5563   ham                                Ard 6 like dat lor.        NaN
# 5564   ham  Why don't you wait 'til at least wednesday to ...        NaN
# 5565   ham                                       Huh y lei...        NaN
# 5566  spam  REMINDER FROM O2: To get 2.50 pounds free call...        NaN
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5563   ham                                Ard 6 like dat lor.        NaN
# 5564   ham  Why don't you wait 'til at least wednesday to ...        NaN
# 5565   ham                                       Huh y lei...        NaN
# 5566  spam  REMINDER FROM O2: To get 2.50 pounds free call...        NaN
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5563        NaN        NaN
# 5564        NaN        NaN
# 5565        NaN        NaN
# 5566        NaN        NaN
# 5567        NaN        NaN

# %%
df.shape
# Out:
# (5568, 5)

# %%
df.describe()
# Out:
#           v1                      v2  \
# count   5568                    5568
# unique     2                    5165
# top      ham  Sorry, I'll call later
# freq    4821                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5568 entries, 0 to 5567
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5568 non-null   object
#  1   v2          5568 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.6+ KB

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5518
# Unnamed: 3    5556
# Unnamed: 4    5562
# dtype: int64

# %%
# Convert the 'label' column to a binary classification problem (spam/ham)
df['label'] = np.where(df['v1'] == 'pam', 1, 0)

# %%
#drop unnecessary columns from database
df.drop(['Unnamed: 2',	'Unnamed: 3' ,	'Unnamed: 4'], axis=1, inplace=True)

# %%
df
# Out:
#         v1                                                 v2  label
# 0      ham  Go until jurong point, crazy.. Available only ...      0
# 1      ham                      Ok lar... Joking wif u oni...      0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...      0
# 3      ham  U dun say so early hor... U c already then say...      0
# 4      ham  Nah I don't think he goes to usf, he lives aro...      0
# ...    ...                                                ...    ...
# 5563   ham                                Ard 6 like dat lor.      0
# 5564   ham  Why don't you wait 'til at least wednesday to ...      0
# 5565   ham                                       Huh y lei...      0
# 5566  spam  REMINDER FROM O2: To get 2.50 pounds free call...      0
# 5567  spam  This is the 2nd time we have tried 2 contact u...      0
#
# [5568 rows x 3 columns]

# %%
# Calculate the proportion of spam and ham messages
spam_proportion = df['label'].mean()
ham_proportion = 1 - spam_proportion
print(f'Spam Proportion: {spam_proportion:.2f}')
print(f'Ham Proportion: {ham_proportion:.2f}')
# Out:
# Spam Proportion: 0.00
# Ham Proportion: 1.00

# %%
# Calculate the average message length for spam and ham messages
avg_spam_length = df[df['label'] == 1]['v2'].apply(len).mean()
avg_ham_length = df[df['label'] == 0]['v2'].apply(len).mean()
print(f'Average Spam Message Length: {avg_spam_length:.2f}')
print(f'Average Ham Message Length: {avg_ham_length:.2f}')
# Out:
# Average Spam Message Length: nan
# Average Ham Message Length: 80.13

# %%
# Plot the distribution of spam and ham messages
sns.countplot(x='v1', data=df)
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.title('Spam vs Ham Messages')
plt.show()

# %%
# Plot the length of spam and ham messages
plt.figure(figsize=(10, 6))
sns.boxplot(x='v1', y='message_length', data=df.assign(message_length=df['v2'].apply(len)))
plt.xlabel('Label')
plt.ylabel('Message Length')
plt.title('Message Length Distribution')
plt.show()
